# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import time
import json

import pandas as pd
from bokeh.io import output_notebook
output_notebook()
bokeh_width, bokeh_height = 500,400

# Import API key
from api_keys_serrano import g_key
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv("Output/2019_2020_mixed_beverage")
df.head()
# Out:
#    taxpayer_number         taxpayer_name                     taxpayer_address  \
# 0      32068897456             HC&K, LLC           7035 W GRAND PKWY S STE 10
# 1      32051593963  J & J ACKERMAN CORP.                           PO BOX 939
# 2      32046106475     FJ RESTAURANT INC  9300 S INTERSTATE 35 STE 8500 # 431
# 3      32054228120    S & KW CORPORATION                 6617 CHIMNEY ROCK RD
# 4      32000861685  FOUNTAIN FOODS, INC.        25600 WESTHEIMER PKWY STE 110
#
#   taxpayer_city taxpayer_state  taxpayer_zip  taxpayer_county  \
# 0      RICHMOND             TX       77407.0               79
# 1       GRANGER             TX       76530.0              246
# 2        AUSTIN             TX       78748.0              227
# 3       HOUSTON             TX       77081.0              101
# 4          KATY             TX       77494.0               79
#
#    location_number             location_name               location_address  \
# ...

# %%
lat, lon = 31.9686,99.9018

# %%
from bokeh.io import show
from bokeh.plotting import gmap
from bokeh.models import GMapOptions

def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(g_key, gmap_options, title='Texas', 
             width=bokeh_width, height=bokeh_height)
    show(p)
    return p

# %%
p = plot(lat, lon)
# Out:
#   <div class="bk-root" id="cdd5c333-f549-4aa9-93da-b30707b0eabb" data-root-id="1421"></div>

# %%
def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(g_key, gmap_options, title='Texas', 
             width=bokeh_width, height=bokeh_height)
    # beware, longitude is on the x axis ;-)
    center = p.circle([lng], [lat], size=10, alpha=0.5, color='red')
    show(p)
    return p

p = plot(lat, lon, map_type='terrain')
# Out:
#   <div class="bk-root" id="7740fcbb-29e6-469b-9fb7-873a71ea224c" data-root-id="1233"></div>
